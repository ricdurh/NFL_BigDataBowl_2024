# %%
from google.colab import drive
drive.mount('/content/drive'  , force_remount=True
)
# Out:
# Mounted at /content/drive

# %%
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)

# %%
# !pip install plotly
# !pip install dash

import plotly
import pandas as pd
import numpy as np
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

games = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/games.csv")
players = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/players.csv")
plays = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/plays.csv")
tackles = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/tackles.csv")
conf_div = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_data/conf_div.csv")

all_players_sorted_7 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_large_pkl/all_players_sorted_7.pkl")
all_players_sorted_8 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_large_pkl/all_players_sorted_8.pkl")
all_players_sorted_9 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_large_pkl/all_players_sorted_9.pkl")

results_df_7_9 = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_data/results_df_7_9.csv", index_col=0)

tackle_data = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_data/tackle_data.csv")
# Out:
# Collecting dash
#   Downloading dash-2.14.2-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/dist-packages (from dash) (3.0.1)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash) (5.15.0)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash) (2.31.0)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html (from dash)
#   Downloading ansi2html-1.9.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash) (1.5.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash) (67.7.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash) (7.0.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash) (23.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2023.11.17)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dash) (1.16.0)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, retrying, ansi2html, dash
# Successfully installed ansi2html-1.9.1 dash-2.14.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 retrying-1.3.4

# %%
import plotly
import pandas as pd
import numpy as np
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
# Out:
# <ipython-input-4-e952e1cb51bd>:5: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# <ipython-input-4-e952e1cb51bd>:6: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
games = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/games.csv")
players = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/players.csv")
plays = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/plays.csv")
tackles = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/tackles.csv")
conf_div = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_data/conf_div.csv")

all_players_sorted_7 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_large_pkl/all_players_sorted_7.pkl")
all_players_sorted_8 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_large_pkl/all_players_sorted_8.pkl")
all_players_sorted_9 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_large_pkl/all_players_sorted_9.pkl")

results_df_7_9 = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_data/results_df_7_9.csv", index_col=0)

tackle_data = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_data/tackle_data.csv")

# %%
all_players_sorted_7 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_large_pkl/all_players_sorted_7.pkl")
all_players_sorted_8 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_large_pkl/all_players_sorted_8.pkl")
all_players_sorted_9 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_large_pkl/all_players_sorted_9.pkl")

results_df_7_9 = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_data/results_df_7_9.csv", index_col=0)

tackle_data = pd.read_csv("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_data/tackle_data.csv")

# %%
players_within_3_5_wks_7_9 = pd.read_pickle("/content/drive/MyDrive/Sports_Projects/NFL_Big_Data_Bowl_2024/final_data/players_within_3_5_wks_7_9.pkl")

# %%
players_within_3_5_wks_7_9
# Out:
#              gameId playId  frameId    nflId          displayName new_pos  \
# 0        2022102000     80       18  37084.0            J.J. Watt      DL
# 1        2022102000     80       18  37110.0          Andy Dalton      QB
# 2        2022102000     80       18  41532.0          James Hurst      OL
# 3        2022102000     80       18  44844.0         Ryan Ramczyk      OL
# 4        2022102000     80       18  44848.0          Budda Baker      DB
# ...             ...    ...      ...      ...                  ...     ...
# 1360277  2022110700   3787       40  54541.0         Travis Jones      DL
# 1360278  2022110700   3787       40  53460.0           Odafe Oweh      LB
# 1360279  2022110700   3787       40  52666.0  Calvin Throckmorton      OL
# 1360280  2022110700   3787       40  54606.0    Damarion Williams      DB
# 1360281  2022110700   3787       40  55125.0           Lewis Kidd      OL
#
#          within_3_yds  within_5_yds defensiveTeam possessionTeam
# 0                   0             0           ARI             NO
# 1                   1             1           ARI             NO
# 2                   0             0           ARI             NO
# 3                   0             0           ARI             NO
# 4                   0             0           ARI             NO
# ...               ...           ...           ...            ...
# 1360277             1             1           BAL             NO
# 1360278             0             0           BAL             NO
# 1360279             1             1           BAL             NO
# 1360280             0             0           BAL             NO
# 1360281             0             1           BAL             NO
#
# [1360282 rows x 10 columns]

# %%
ARI_players = ['Antwaun Woods', 'J.J. Watt', 'Jonathan Ledbetter', 'Leki Fotu', 'Michael Dogbe', 'Rashard Lawrence', 'Zach Allen', 'Ben Niemann', 'Cameron Thomas', 'Ezekiel Turner', 'Jesse Luketa',
               'Markus Golden', 'Myjai Sanders', 'Tanner Vallejo', 'Victor Dimukeje', 'Zaven Collins', 'Antonio Hamilton', 'Budda Baker', 'Byron Murphy', 'Chris Banjo', 'Isaiah Simmons', 'Jalen Thompson', 'Marco Wilson']

ARI_players_within_3_5_wks_7_9 = players_within_3_5_wks_7_9[players_within_3_5_wks_7_9['defensiveTeam'] == 'ARI']

# %%
ARI_players = ['Antwaun Woods', 'J.J. Watt', 'Jonathan Ledbetter', 'Leki Fotu', 'Michael Dogbe', 'Rashard Lawrence', 'Zach Allen', 'Ben Niemann', 'Cameron Thomas', 'Ezekiel Turner', 'Jesse Luketa',
               'Markus Golden', 'Myjai Sanders', 'Tanner Vallejo', 'Victor Dimukeje', 'Zaven Collins', 'Antonio Hamilton', 'Budda Baker', 'Byron Murphy', 'Chris Banjo', 'Isaiah Simmons', 'Jalen Thompson', 'Marco Wilson']

# %%
ARI_players_within_3_5_wks_7_9 = players_within_3_5_wks_7_9[players_within_3_5_wks_7_9['defensiveTeam'] == 'ARI']

# %%
# Out:
#                   Name  Num DTC
# 0          Budda Baker       15
# 1        Markus Golden       12
# 2        Zaven Collins       11
# 3           Zach Allen       11
# 4       Jalen Thompson       10
# 5       Isaiah Simmons        9
# 6            J.J. Watt        8
# 7       Tanner Vallejo        7
# 8      Victor Dimukeje        6
# 9            Leki Fotu        6
# 10  Jonathan Ledbetter        5
# 11         Ben Niemann        5
# 12        Marco Wilson        4
# 13       Myjai Sanders        2
# 14      Cameron Thomas        2
# 15       Antwaun Woods        2
# 16    Rashard Lawrence        1
# 17    Antonio Hamilton        1
# 18       Michael Dogbe        1
# 19      Ezekiel Turner        1
# 20         Chris Banjo        1
# 21        Byron Murphy        1
# 22        Jesse Luketa        1

# %%
team_breakdown
# Out:
#                   Name Pos  # Plays  Total Time  <5yds  <3yds  Closest Def  \
# 0        Zaven Collins  LB       66       220.9  106.0   52.1         17.3
# 1         Byron Murphy  DB       66       220.9   15.3    7.8          0.5
# 2          Budda Baker  DB       65       217.2   87.5   57.5         20.3
# 3       Jalen Thompson  DB       65       217.2   56.9   41.9         15.2
# 4           Zach Allen  DL       51       170.3   99.6   52.4         25.6
# 5         Marco Wilson  DB       51       172.7   31.9   16.0          8.4
# 6            J.J. Watt  DL       48       162.8   93.1   42.3         22.3
# 7      Victor Dimukeje  LB       42       137.6   54.0   23.1         15.8
# 8        Markus Golden  LB       42       146.3   77.9   40.0         18.6
# 9            Leki Fotu  DL       42       142.5   72.9   38.9         14.3
# 10      Isaiah Simmons  DB       42       139.1   55.3   37.5         10.1
# 11         Ben Niemann  LB       37       123.4   63.1   32.9          6.1
# 12      Tanner Vallejo  LB       29        97.5   53.9   33.0          8.4
# 13  Jonathan Ledbetter  DL       25        83.5   51.5   30.8         11.6
# 14       Michael Dogbe  DL       14        42.9   34.1   16.2          5.3
# 15        Jesse Luketa  LB        8        21.5    7.2    2.7          3.2
# 16       Myjai Sanders  LB        8        31.4   23.9   15.7          5.3
# 17       Antwaun Woods  DL        7        25.0   13.8    7.0          1.9
# 18    Antonio Hamilton  DB        6        14.2    4.1    2.5          0.8
# 19      Cameron Thomas  LB        4        15.5   13.9   10.1          2.7
# 20         Chris Banjo  DB        4        12.7    3.6    2.2          0.5
# 21    Rashard Lawrence  DL        3        11.1    9.0    6.3          4.6
#
#     2nd Def  3rd Def  Num DTC  Sum DTC  DTC/<5yds  DTC/<3yds
# 0      23.9     20.2       11     4.65       0.04       0.09
# 1       1.6      3.3        1     0.38       0.02       0.05
# 2      13.0     15.5       15     8.93       0.10       0.16
# 3      13.5      8.2       10     3.93       0.07       0.09
# 4      21.6     22.3       11     4.40       0.04       0.08
# 5       5.6      5.6        4     2.81       0.09       0.18
# 6      19.8     23.5        8     3.71       0.04       0.09
# 7      13.2     15.5        6     3.85       0.07       0.17
# 8      16.0     10.7       12     5.52       0.07       0.14
# 9      17.7     20.0        6     2.68       0.04       0.07
# 10     12.4     12.6        9     4.66       0.08       0.12
# 11      9.3     15.3        5     2.26       0.04       0.07
# 12     11.8     13.3        7     3.50       0.06       0.11
# 13     15.0     13.0        5     1.32       0.03       0.04
# 14      6.3      9.0        1     0.45       0.01       0.03
# 15      1.0      1.0        1     1.00       0.14       0.37
# 16      6.7      3.7        2     1.20       0.05       0.08
# 17      4.0      5.2        2     0.56       0.04       0.08
# 18      0.9      0.8        1     0.59       0.14       0.24
# 19      5.2      0.3        2     1.63       0.12       0.16
# 20      0.1      0.9        1     0.32       0.09       0.15
# 21      1.9      0.8        1     0.64       0.07       0.10

# %%
name_pos_plays = ARI_players_within_3_5_wks_7_9.groupby(['displayName', 'new_pos'])['playId'].nunique().reset_index().sort_values(['playId'], ascending=False).reset_index(drop=True)
name_pos_plays = name_pos_plays.rename(columns={'displayName': 'Name', 'new_pos': 'Pos', 'playId': '# Plays'})

name_pos_sec = ARI_players_within_3_5_wks_7_9.groupby(['displayName', 'new_pos'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
name_pos_sec = name_pos_sec.rename(columns={'displayName': 'Name', 'new_pos': 'Pos', 'frameId': 'Total Time'})
name_pos_sec['Total Time'] = name_pos_sec['Total Time'] / 10

name_pos_wi_5 = ARI_players_within_3_5_wks_7_9[ARI_players_within_3_5_wks_7_9['within_5_yds'] == 1].groupby(['displayName', 'new_pos'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
name_pos_wi_5 = name_pos_wi_5.rename(columns={'displayName': 'Name', 'new_pos': 'Pos', 'frameId': '<5yds'})
name_pos_wi_5['<5yds'] = name_pos_wi_5['<5yds'] / 10

name_pos_wi_3 = ARI_players_within_3_5_wks_7_9[ARI_players_within_3_5_wks_7_9['within_3_yds'] == 1].groupby(['displayName', 'new_pos'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
name_pos_wi_3 = name_pos_wi_3.rename(columns={'displayName': 'Name', 'new_pos': 'Pos', 'frameId': '<3yds'})
name_pos_wi_3['<3yds'] = name_pos_wi_3['<3yds'] / 10

all_players_sorted_7_9 = pd.concat([all_players_sorted_7, all_players_sorted_8, all_players_sorted_9])
ARI_aps_7_9 = all_players_sorted_7_9[all_players_sorted_7_9['displayName'].isin(ARI_players)]

name_pos_nearest = ARI_aps_7_9[ARI_aps_7_9['rank'] == 2].groupby(['displayName'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
name_pos_nearest = name_pos_nearest.rename(columns={'displayName': 'Name', 'frameId': 'Closest Def'})
name_pos_nearest['Closest Def'] = name_pos_nearest['Closest Def'] / 10

name_pos_2nd_nearest = ARI_aps_7_9[ARI_aps_7_9['rank'] == 3].groupby(['displayName'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
name_pos_2nd_nearest = name_pos_2nd_nearest.rename(columns={'displayName': 'Name', 'frameId': '2nd Def'})
name_pos_2nd_nearest['2nd Def'] = name_pos_2nd_nearest['2nd Def'] / 10

name_pos_3rd_nearest = ARI_aps_7_9[ARI_aps_7_9['rank'] == 4].groupby(['displayName'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
name_pos_3rd_nearest = name_pos_3rd_nearest.rename(columns={'displayName': 'Name', 'frameId': '3rd Def'})
name_pos_3rd_nearest['3rd Def'] = name_pos_3rd_nearest['3rd Def'] / 10

ARI_DTC = tackle_data[tackle_data['defensiveTeam'] == 'ARI']

name_pos_sum_DTC = ARI_DTC.groupby(['def1_name'])['new_prop'].sum().reset_index().sort_values(['new_prop'], ascending=False).reset_index(drop=True)
name_pos_sum_DTC = name_pos_sum_DTC.rename(columns={'def1_name': 'Name', 'new_prop': 'Sum DTC'})
name_pos_sum_DTC['Sum DTC'] = round(name_pos_sum_DTC['Sum DTC'], 2)

name_pos_num_DTC = ARI_DTC.groupby(['def1_name'])['new_prop'].count().reset_index().sort_values(['new_prop'], ascending=False).reset_index(drop=True)
name_pos_num_DTC = name_pos_num_DTC.rename(columns={'def1_name': 'Name', 'new_prop': 'Num DTC'})

team_breakdown = name_pos_plays.merge(name_pos_sec).merge(name_pos_wi_5).merge(name_pos_wi_3).merge(name_pos_nearest).merge(name_pos_2nd_nearest).merge(name_pos_3rd_nearest).merge(name_pos_num_DTC).merge(name_pos_sum_DTC)

team_breakdown['DTC/<5yds'] = round(team_breakdown['Sum DTC'] / team_breakdown['<5yds'], 2)
team_breakdown['DTC/<3yds'] = round(team_breakdown['Sum DTC'] / team_breakdown['<3yds'], 2)

# Create the bubble chart
fig = px.scatter(
    team_breakdown,
    x='<3yds',
    y='Total Time',
    size='DTC/<3yds',  # Size of bubbles
    color='Pos',  # Color of bubbles (optional, can be another variable)
    hover_name='Name',  # Hover text
    size_max=60  # Maximum bubble size
)

# Update layout if necessary
fig.update_layout(
    title='Team Breakdown Bubble Chart',
    xaxis_title='<3 Yards Time',
    yaxis_title='Total Time',
    legend_title='Position'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3a3c81a-e451-4bfe-b23b-2dc0eb226e7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3a3c81a-e451-4bfe-b23b-2dc0eb226e7d")) {                    Plotly.newPlot(                        "a3a3c81a-e451-4bfe-b23b-2dc0eb226e7d",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePos=LB\u003cbr\u003e\u003c3yds=%{x}\u003cbr\u003eTotal Time=%{y}\u003cbr\u003eDTC\u002f\u003c3yds=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Zaven Collins","Victor Dimukeje","Markus Golden","Ben Niemann","Tanner Vallejo","Jesse Luketa","Myjai Sanders","Cameron Thomas"],"legendgroup":"LB","marker":{"color":"#636efa","size":[0.09,0.17,0.14,0.07,0.11,0.37,0.08,0.16],"sizemode":"area","sizeref":0.00010277777777777778,"symbol":"circle"},"mode":"markers","name":"LB","orientation":"v","showlegend":true,"x":[52.1,23.1,40.0,32.9,33.0,2.7,15.7,10.1],"xaxis":"x","y":[220.9,137.6,146.3,123.4,97.5,21.5,31.4,15.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePos=DB\u003cbr\u003e\u003c3yds=%{x}\u003cbr\u003eTotal Time=%{y}\u003cbr\u003eDTC\u002f\u003c3yds=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Byron Murphy","Budda Baker","Jalen Thompson","Marco Wilson","Isaiah Simmons","Antonio Hamilton","Chris Banjo"],"legendgroup":"DB","marker":{"color":"#EF553B","size":[0.05,0.16,0.09,0.18,0.12,0.24,0.15],"sizemode":"area","sizeref":0.00010277777777777778,"symbol":"circle"},"mode":"markers","name":"DB","orientation":"v","showlegend":true,"x":[7.8,57.5,41.9,16.0,37.5,2.5,2.2],"xaxis":"x","y":[220.9,217.2,217.2,172.7,139.1,14.2,12.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePos=DL\u003cbr\u003e\u003c3yds=%{x}\u003cbr\u003eTotal Time=%{y}\u003cbr\u003eDTC\u002f\u003c3yds=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Zach Allen","J.J. Watt","Leki Fotu","Jonathan Ledbetter","Michael Dogbe","Antwaun Woods","Rashard Lawrence"],"legendgroup":"DL","marker":{"color":"#00cc96","size":[0.08,0.09,0.07,0.04,0.03,0.08,0.1],"sizemode":"area","sizeref":0.00010277777777777778,"symbol":"circle"},"mode":"markers","name":"DL","orientation":"v","showlegend":true,"x":[52.4,42.3,38.9,30.8,16.2,7.0,6.3],"xaxis":"x","y":[170.3,162.8,142.5,83.5,42.9,25.0,11.1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"# ...

# %%
tackle_data

#results_df_7_9
# Out:
#                  def1_name def1_pos defensiveTeam possessionTeam  new_prop  \
# 0              Budda Baker       DB           ARI             NO  0.679478
# 1           Jalen Thompson       DB           ARI             NO  0.320522
# 2         Rashard Lawrence       DL           ARI             NO  0.641223
# 3            Zaven Collins       LB           ARI             NO  0.358777
# 4           Tyrann Mathieu       DB            NO            ARI  0.511015
# ...                    ...      ...           ...            ...       ...
# 3317           Marcus Maye       DB            NO            BAL  0.294283
# 3318          Kaden Elliss       LB            NO            BAL  0.705717
# 3319       Carl Granderson       DL            NO            BAL  1.000000
# 3320  Broderick Washington       DL           BAL             NO  0.552720
# 3321          Travis Jones       DL           BAL             NO  0.447280
#
#       week  third_down_failed  fourth_down_failed  3rd or 4th stop  \
# 0        7                  0                   0                0
# 1        7                  0                   0                0
# 2        7                  0                   0                0
# 3        7                  0                   0                0
# 4        7                  0                   0                0
# ...    ...                ...                 ...              ...
# 3317     9                  0                   0                0
# 3318     9                  0                   0                0
# 3319     9                  1                   0                1
# 3320     9                  0                   0                0
# 3321     9                  0                   0                0
#
#       goal_to_go  ...  run_location run_gap_location 3rd or 4th failed  \
# 0              0  ...        middle           middle                 0
# 1              0  ...        middle           middle                 0
# 2              0  ...        middle           middle                 0
# 3              0  ...        middle           middle                 0
# 4              0  ...        middle           middle                 0
# ...          ...  ...           ...              ...               ...
# 3317           0  ...         right        right end                 0
# 3318           0  ...         right        right end                 0
# 3319           0  ...          left         left end                 1
# 3320           0  ...         right      right guard                 0
# 3321           0  ...         right      right guard                 0
#
#            epa  neg epa  sum prod neg epa  3rd or 4th  goal to go  TFL  \
# 0     1.318386        0          0.000000         0.0         0.0  0.0
# 1     1.318386        0          0.000000         0.0         0.0  0.0
# 2    -0.152057        1          0.641223         0.0         0.0  0.0
# 3    -0.152057        1          0.358777         0.0         0.0  0.0
# 4     0.279343        0          0.000000         0.0         0.0  0.0
# ...        ...      ...               ...         ...         ...  ...
# 3317 -0.149736        1          0.294283         0.0         0.0  0.0
# 3318 -0.149736        1          0.705717         0.0         0.0  0.0
# 3319 -1.144850        1          1.000000         1.0         0.0  1.0
# 3320 -0.099311        1          0.552720         0.0         0.0  0.0
# 3321 -0.099311        1          0.447280         0.0         0.0  0.0
#
#          epa.1
# 0     0.895815
# 1     0.422572
# 2    -0.097502
# 3    -0.054555
# 4     0.142748
# ...        ...
# 3317 -0.044065
# 3318 -0.105671
# 3319 -1.144850
# 3320 -0.054891
# 3321 -0.044420
#
# [3322 rows x 22 columns]

# %%
d_players_within_3_5_wks_7_9 = players_within_3_5_wks_7_9[players_within_3_5_wks_7_9['new_pos'].isin(['DB', 'DL', 'LB'])]

b = d_players_within_3_5_wks_7_9.groupby(['displayName', 'new_pos'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
b = b.rename(columns={'frameId': 'sec'})
b['sec'] = b['sec'] / 10

a = d_players_within_3_5_wks_7_9[d_players_within_3_5_wks_7_9['within_5_yds'] == 1].groupby(['displayName', 'new_pos'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
a = a.rename(columns={'frameId': '<5yds'})
a['<5yds'] = a['<5yds'] / 10

c = d_players_within_3_5_wks_7_9[d_players_within_3_5_wks_7_9['within_3_yds'] == 1].groupby(['displayName', 'new_pos'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
c = c.rename(columns={'frameId': '<3yds'})
c['<3yds'] = c['<3yds'] / 10

d = tackle_data.groupby(['def1_name'])['new_prop'].sum().reset_index().sort_values(['new_prop'], ascending=False).reset_index(drop=True)
d = d.rename(columns={'def1_name': 'displayName'})

dd = tackle_data.groupby(['def1_name'])['neg epa'].sum().reset_index().sort_values(['neg epa'], ascending=False).reset_index(drop=True)
dd = dd.rename(columns={'def1_name': 'displayName', 'neg epa': '# DTC (-EPA)'})

e = a.merge(b).merge(c).merge(d).merge(dd)

e['DTC/<5yds'] = round(e['new_prop'] / e['<5yds'], 3)
e['DTC/<3yds'] = round(e['new_prop'] / e['<3yds'], 3)
e['# DTC (-EPA)'] = round(e['# DTC (-EPA)'], 3)

e

# %%
e_100 = e.sort_values(['<3yds'], ascending=False).head(100).reset_index(drop=True)

# %%
e_100
# Out:
#            displayName new_pos  <5yds    sec  <3yds   new_prop  # DTC (-EPA)  \
# 4        Shaq Thompson      LB  146.9  245.4  106.0  13.111862             8
# 3    Yetur Gross-Matos      LB  154.0  212.9  102.3   8.182828             9
# 2         Mykal Walker      LB  156.0  230.4  100.7  11.597233            14
# 1       Grover Stewart      DL  156.1  192.0  100.7  10.078365            14
# 0          Kenny Clark      DL  159.0  233.8   90.4   6.531975             9
# ..                 ...     ...    ...    ...    ...        ...           ...
# 111       Roquan Smith      LB   75.1  142.2   45.4   8.295737            10
# 163      John Ridgeway      DL   61.4   71.8   45.1   2.733643             6
# 102      Jordyn Brooks      LB   78.3  149.1   44.8   7.910805            12
# 115  Abdullah Anderson      DL   73.7   97.1   44.5   3.173765             6
# 126        Marcus Maye      DB   71.1  208.3   44.4   4.869965             5
#
#      DTC/<5yds  DTC/<3yds
# 4        0.089      0.124
# 3        0.053      0.080
# 2        0.074      0.115
# 1        0.065      0.100
# 0        0.041      0.072
# ..         ...        ...
# 111      0.110      0.183
# 163      0.045      0.061
# 102      0.101      0.177
# 115      0.043      0.071
# 126      0.068      0.110
#
# [100 rows x 9 columns]

# %%
# Create the bubble chart
fig = px.scatter(
    e_100,
    x='<3yds',
    y='sec',
    size='DTC/<3yds',  # Size of bubbles
    color='new_pos',  # Color of bubbles (optional, can be another variable)
    hover_name='displayName',  # Hover text
    size_max=30  # Maximum bubble size
)

# Update layout if necessary
fig.update_layout(
    title='Team Breakdown Bubble Chart',
    xaxis_title='<3 Yards Time',
    yaxis_title='Total Time',
    legend_title='Position'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="02f617be-e822-4192-b88b-17da4467f151" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02f617be-e822-4192-b88b-17da4467f151")) {                    Plotly.newPlot(                        "02f617be-e822-4192-b88b-17da4467f151",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003enew_pos=LB\u003cbr\u003e\u003c3yds=%{x}\u003cbr\u003esec=%{y}\u003cbr\u003eDTC\u002f\u003c3yds=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Shaq Thompson","Yetur Gross-Matos","Mykal Walker","Zaire Franklin","Rashaan Evans","Germaine Pratt","Ja'Whaun Bentley","Quay Walker","Devin Lloyd","Foyesade Oluokun","Christian Kirksey","Frankie Luvu","Christian Harris","Josh Allen","Bobby Okereke","Preston Smith","Drue Tranquill","Devin White","C.J. Mosley","Lavonte David","Brian Burns","Bradley Chubb","Jamin Davis","De'Vondre Campbell","Alex Anzalone","Tremaine Edmunds","Jahlani Tavai","Elandon Roberts","Rashan Gary","Bobby Wagner","Jaelan Phillips","Jerome Baker","Lorenzo Carter","Demario Davis","Patrick Queen","Pete Werner","Denzel Perryman","Ernest Jones","Zaven Collins","T.J. Edwards","Leighton Vander Esch","Divine Deablo","Logan Wilson","Nicholas Morrow","Travon Walker","Blake Martinez","Jordan Hicks","Kenneth Murray","Quincy Williams","Roquan Smith","Jordyn Brooks"],"legendgroup":"LB","marker":{"color":"#636efa","size":[0.124,0.08,0.115,0.111,0.118,0.115,0.123,0.15,0.079,0.117,0.145,0.08,0.075,0.084,0.132,0.102,0.135,0.075,0.104,0.099,0.11,0.085,0.078,0.106,0.145,0.136,0.062,0.087,0.101,0.116,0.119,0.083,0.086,0.07,0.118,0.109,0.168,0.085,0.089,0.11,0.172,0.17,0.06,0.142,0.09,0.142,0.159,0.179,0.109,0.183,0.177],"sizemode":"area","sizeref":0.00020333333333333333,"symbol":"circle"},"mode":"markers","name":"LB","orientation":"v","showlegend":true,"x":[106.0,102.3,100.7,88.7,88.7,85.0,80.0,74.5,74.0,72.3,71.7,71.7,70.9,70.0,69.1,69.0,66.5,65.9,64.4,63.5,62.6,61.3,61.3,61.1,60.7,60.7,60.5,60.1,58.2,57.1,56.9,56.9,55.4,54.7,54.7,53.6,53.5,53.3,52.1,51.8,51.4,51.0,50.5,50.4,50.3,49.1,48.8,46.4,46.1,45.4,44.8],"xaxis":"x","y":[245.4,212.9,230.4,234.8,226.8,220.4,195.1,193.5,232.4,240.0,261.6,183.4,243.7,193.0,171.6,244.1,221.2,241.8,209.0,241.8,211.2,198.8,180.9,188.7,199.9,185.5,157.1,173.6,170.5,147.0,152.1,172.8,194.8,208.3,154.6,153.6,174.9,129.5,220.9,139.5,176.9,124.8,152.0,156.8,196.8,149.1,119.5,171.3,175.6,142.2,149.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003enew_pos=DL\u003cbr\u003e\u003c3yds=%{x}\u003cbr\u003esec=%{y}\u003cbr\u003eDTC\u002f\u003c3yds=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Grover Stewart","Kenny Clark","Lawrence Guy","Derrick Brown","Dean Lowry","Zachary Carter","Davon Godchaux","DeForest Buckner","Jarran Reed","Andrew Billings","Folorunso Fatukasi","B.J. Hill","Davon Hamilton","Maxx Crosby","Zach Sieler","Montez Sweat","Daron Payne","Jonathan Allen","Sebastian Joseph","Ta'Quon Graham","Grady Jarrett","William Gholston","Jay Tufele","Deatrich Wise","Christian Wilkins","Rakeem Nunez-Roches","Roy Robertson-Harris","Zach Allen","Dre'Mont Jones","Matt Ioannidis","Vita Vea","Aaron Donald","Bilal Nichols","Tedarrell Slaton","Sam Hubbard","A'Shawn Robinson","Leonard Williams","John Ridgeway","Abdullah Anderson"],"legendgroup":"DL","marker":{"color":"#EF553B","size":[0.1,0.072,0.099,0.1,0.068,0.084,0.092,0.122,0.098,0.114,0.082,0.138,0.115,0.136,0.102,0.052,0.108,0.095,0.069,0.122,0.075,0.108,0.067,0.076,0.072,0.044,0.071,0.084,0.09,0.036,0.093,0.101,0.074,0.049,0.067,0.087,0.126,0.061,0.071],"sizemode":"area","sizeref":0.00020333333333333333,"sy ...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

team_b = d_players_within_3_5_wks_7_9.groupby(['defensiveTeam', 'new_pos'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
team_b = team_b.rename(columns={'frameId': 'sec'})
team_b['sec'] = team_b['sec'] / 10

team_a = d_players_within_3_5_wks_7_9[d_players_within_3_5_wks_7_9['within_5_yds'] == 1].groupby(['defensiveTeam', 'new_pos'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
team_a = team_a.rename(columns={'frameId': '<5yds'})
team_a['<5yds'] = team_a['<5yds'] / 10

team_c = d_players_within_3_5_wks_7_9[d_players_within_3_5_wks_7_9['within_3_yds'] == 1].groupby(['defensiveTeam', 'new_pos'])['frameId'].count().reset_index().sort_values(['frameId'], ascending=False).reset_index(drop=True)
team_c = team_c.rename(columns={'frameId': '<3yds'})
team_c['<3yds'] = team_c['<3yds'] / 10

team_d = tackle_data.groupby(['defensiveTeam', 'def1_pos'])['new_prop'].sum().reset_index().sort_values(['new_prop'], ascending=False).reset_index(drop=True)
team_d = team_d.rename(columns= {'def1_pos': 'new_pos'})

team_dd = tackle_data.groupby(['defensiveTeam', 'def1_pos'])['neg epa'].sum().reset_index().sort_values(['neg epa'], ascending=False).reset_index(drop=True)
team_dd = team_dd.rename(columns={'neg epa': '# DTC (-EPA)', 'def1_pos': 'new_pos'})

team_e = team_a.merge(team_b).merge(team_c).merge(team_d).merge(team_dd)

team_e['DTC/<5yds'] = round(team_e['new_prop'] / team_e['<5yds'], 3)
team_e['DTC/<3yds'] = round(team_e['new_prop'] / team_e['<3yds'], 3)
team_e['# DTC (-EPA)'] = round(team_e['# DTC (-EPA)'], 3)

num_plays = team_e.groupby(['defensiveTeam'])['new_prop'].sum().reset_index()
num_plays = num_plays.rename(columns={'new_prop': 'num_plays'})

team_e = team_e.merge(num_plays)
team_e['Pos % of DTC'] = round(team_e['new_prop'] / team_e['num_plays'], 3)

conf_div = conf_div.rename(columns={'Team': 'defensiveTeam'})


team_e = team_e.merge(conf_div)

team_e['Team-Pos'] = team_e['defensiveTeam'] + "-" + team_e['new_pos']

app = dash.Dash(__name__)

# App Layout
app.layout = html.Div([
    dcc.Dropdown(
        id='conference-filter',
        options=[{'label': 'All', 'value': 'All'}] +
                [{'label': conf, 'value': conf} for conf in team_e['Conference'].unique()],
        value='All',
        placeholder="Select a conference"
    ),
    dcc.Dropdown(
        id='division-filter',
        options=[{'label': 'All', 'value': 'All'}] +
                [{'label': div, 'value': div} for div in team_e['Division'].unique()],
        value='All',
        placeholder="Select a division"
    ),
    dcc.Dropdown(
        id='position-filter',
        options=[{'label': 'All', 'value': 'All'}] +
                [{'label': pos, 'value': pos} for pos in team_e['new_pos'].unique()],
        value='All',
        placeholder="Select a position"
    ),
    dcc.Graph(id='bubble-chart')
])


# Callback for updating the bubble chart
@app.callback(
    Output('bubble-chart', 'figure'),
    [Input('conference-filter', 'value'),
     Input('division-filter', 'value'),
     Input('position-filter', 'value')]
)
def update_chart(selected_conference, selected_division, selected_position):
    filtered_data = team_e.copy()

    # Apply filters only if the option is not 'All'
    if selected_conference != 'All':
        filtered_data = filtered_data[filtered_data['Conference'] == selected_conference]
    if selected_division != 'All':
        filtered_data = filtered_data[filtered_data['Division'] == selected_division]
    if selected_position != 'All':
        filtered_data = filtered_data[filtered_data['new_pos'] == selected_position]




    # Create the bubble chart
    fig = px.scatter(
        filtered_data,
        x='<3yds',
        y='sec',
        size='Pos % of DTC',
        color='new_pos',
        hover_name='Team-Pos',
        text='defensiveTeam',
        size_max=30
    )

    return fig

if __name__ == '__main__':
    app.run_server(debug=True)

# %%
# # Create the bubble chart
# fig = px.scatter(
#     team_e,
#     x='<3yds',
#     y='sec',
#     size='Pos % of DTC',  # Size of bubbles
#     color='new_pos',  # Color of bubbles (optional, can be another variable)
#     hover_name='defensiveTeam',  # Hover text
#     text='defensiveTeam',
#     size_max=40  # Maximum bubble size
# )

# # Update layout if necessary
# fig.update_layout(
#     title='Team Breakdown Bubble Chart',
#     xaxis_title='<3 Yards Time',
#     yaxis_title='Total Time',
#     legend_title='Position'
# )

# fig.show()

# %%
name_pos_2nd_nearest
# Out:
#                   Name  2nd Def
# 0        Zaven Collins     23.9
# 1           Zach Allen     21.6
# 2            J.J. Watt     19.8
# 3            Leki Fotu     17.7
# 4        Markus Golden     16.0
# 5   Jonathan Ledbetter     15.0
# 6       Jalen Thompson     13.5
# 7      Victor Dimukeje     13.2
# 8          Budda Baker     13.0
# 9       Isaiah Simmons     12.4
# 10      Tanner Vallejo     11.8
# 11         Ben Niemann      9.3
# 12       Myjai Sanders      6.7
# 13       Michael Dogbe      6.3
# 14        Marco Wilson      5.6
# 15      Cameron Thomas      5.2
# 16       Antwaun Woods      4.0
# 17    Rashard Lawrence      1.9
# 18        Byron Murphy      1.6
# 19        Jesse Luketa      1.0
# 20    Antonio Hamilton      0.9
# 21      Ezekiel Turner      0.2
# 22         Chris Banjo      0.1

# %%
ARI_aps_7_9
# Out:
#            gameId playId  frameId_x  event_x  frameId_y    event_y  \
# 1      2022102000     80         18  handoff         59     tackle
# 2      2022102000     80         18  handoff         59     tackle
# 3      2022102000     80         18  handoff         59     tackle
# 5      2022102000     80         18  handoff         59     tackle
# 6      2022102000     80         18  handoff         59     tackle
# ...           ...    ...        ...      ...        ...        ...
# 57830  2022110608   4083         18  handoff         65  touchdown
# 57831  2022110608   4083         18  handoff         65  touchdown
# 57833  2022110608   4083         18  handoff         65  touchdown
# 57834  2022110608   4083         18  handoff         65  touchdown
# 57835  2022110608   4083         18  handoff         65  touchdown
#
#        ballCarrierId ballCarrierDisplayName playDirection    nflId  ...  \
# 1              44879           Alvin Kamara          left  52539.0  ...
# 2              44879           Alvin Kamara          left  47848.0  ...
# 3              44879           Alvin Kamara          left  37084.0  ...
# 5              44879           Alvin Kamara          left  52539.0  ...
# 6              44879           Alvin Kamara          left  47848.0  ...
# ...              ...                    ...           ...      ...  ...
# 57830          54506         Kenneth Walker          left  48473.0  ...
# 57831          54506         Kenneth Walker          left  45008.0  ...
# 57833          54506         Kenneth Walker          left  44848.0  ...
# 57834          54506         Kenneth Walker          left  48473.0  ...
# 57835          54506         Kenneth Walker          left  45008.0  ...
#
#       min_distance angle_for_min_distance  second_min_distance  \
# 1         0.964624             287.495758             2.132159
# 2         0.842021              15.851928             1.160689
# 3         0.948103             333.705210             1.706986
# 5         0.905207             286.032339             2.041666
# 6         0.819329              19.983107             1.132828
# ...            ...                    ...                  ...
# 57830     1.398463             234.605204             3.718400
# 57831     0.958593             339.863697             2.840158
# 57833     0.539073             220.486012             2.895272
# 57834     1.528987             222.349310             3.738155
# 57835     1.024744             331.434163             3.095174
#
#        angle_for_second_min_distance  max_distance  actual_dist_from_final  \
# 1                         299.811543         73.86                   22.74
# 2                          88.025066         73.86                   22.74
# 3                         218.817070         73.86                   22.74
# 5                         302.600334         73.44                   22.32
# 6                          94.049582         73.44                   22.32
# ...                              ...           ...                     ...
# 57830                     253.758286          0.05                     0.1
# 57831                     283.644818          0.05                     0.1
# 57833                     259.854456             0                    0.05
# 57834                     250.789521             0                    0.05
# 57835                     284.979114             0                    0.05
#
#        std_x_nb  std_y_nb  std_bc_x std_bc_y
# 1         78.79     24.22     83.86    24.56
# 2         79.04     22.14     83.86    24.56
# 3         79.71     29.03     83.86    24.56
# 5         78.74     23.78     83.44    24.24
# 6         79.07     21.78     83.44    24.24
# ...         ...       ...       ...      ...
# 57830     10.92     53.04     10.05    52.90
# 57831      9.21     52.23     10.05    52.90
# 57833     10.29     52.46      9.95    53.15
# 57834     11.01     53.14      9.95    53.15
# 57835      8.98     52.60      9.95    53.15
#
# [6621 rows x 67 columns]

# %%
name_pos_wi_3
# Out:
#                   Name Pos  Time < 3yds
# 0          Budda Baker  DB         57.5
# 1           Zach Allen  DL         52.4
# 2        Zaven Collins  LB         52.1
# 3            J.J. Watt  DL         42.3
# 4       Jalen Thompson  DB         41.9
# 5        Markus Golden  LB         40.0
# 6            Leki Fotu  DL         38.9
# 7       Isaiah Simmons  DB         37.5
# 8       Tanner Vallejo  LB         33.0
# 9          Ben Niemann  LB         32.9
# 10  Jonathan Ledbetter  DL         30.8
# 11     Victor Dimukeje  LB         23.1
# 12       Michael Dogbe  DL         16.2
# 13        Marco Wilson  DB         16.0
# 14       Myjai Sanders  LB         15.7
# 15      Cameron Thomas  LB         10.1
# 16        Byron Murphy  DB          7.8
# 17       Antwaun Woods  DL          7.0
# 18    Rashard Lawrence  DL          6.3
# 19        Jesse Luketa  LB          2.7
# 20    Antonio Hamilton  DB          2.5
# 21         Chris Banjo  DB          2.2
# 22      Ezekiel Turner  LB          1.8

# %%
name_pos_wi_5
# Out:
#                   Name Pos  Time < 5yds
# 0        Zaven Collins  LB        106.0
# 1           Zach Allen  DL         99.6
# 2            J.J. Watt  DL         93.1
# 3          Budda Baker  DB         87.5
# 4        Markus Golden  LB         77.9
# 5            Leki Fotu  DL         72.9
# 6          Ben Niemann  LB         63.1
# 7       Jalen Thompson  DB         56.9
# 8       Isaiah Simmons  DB         55.3
# 9      Victor Dimukeje  LB         54.0
# 10      Tanner Vallejo  LB         53.9
# 11  Jonathan Ledbetter  DL         51.5
# 12       Michael Dogbe  DL         34.1
# 13        Marco Wilson  DB         31.9
# 14       Myjai Sanders  LB         23.9
# 15        Byron Murphy  DB         15.3
# 16      Cameron Thomas  LB         13.9
# 17       Antwaun Woods  DL         13.8
# 18    Rashard Lawrence  DL          9.0
# 19        Jesse Luketa  LB          7.2
# 20    Antonio Hamilton  DB          4.1
# 21         Chris Banjo  DB          3.6
# 22      Ezekiel Turner  LB          2.6

# %%
name_pos_sec
# Out:
#                   Name Pos  Time (sec)
# 0        Zaven Collins  LB       220.9
# 1         Byron Murphy  DB       220.9
# 2          Budda Baker  DB       217.2
# 3       Jalen Thompson  DB       217.2
# 4         Marco Wilson  DB       172.7
# 5           Zach Allen  DL       170.3
# 6            J.J. Watt  DL       162.8
# 7        Markus Golden  LB       146.3
# 8            Leki Fotu  DL       142.5
# 9       Isaiah Simmons  DB       139.1
# 10     Victor Dimukeje  LB       137.6
# 11         Ben Niemann  LB       123.4
# 12      Tanner Vallejo  LB        97.5
# 13  Jonathan Ledbetter  DL        83.5
# 14       Michael Dogbe  DL        42.9
# 15       Myjai Sanders  LB        31.4
# 16       Antwaun Woods  DL        25.0
# 17        Jesse Luketa  LB        21.5
# 18      Cameron Thomas  LB        15.5
# 19    Antonio Hamilton  DB        14.2
# 20         Chris Banjo  DB        12.7
# 21    Rashard Lawrence  DL        11.1
# 22      Ezekiel Turner  LB         3.7

# %%
name_pos_plays
# Out:
#                   Name Pos  # Plays
# 0        Zaven Collins  LB       66
# 1         Byron Murphy  DB       66
# 2          Budda Baker  DB       65
# 3       Jalen Thompson  DB       65
# 4           Zach Allen  DL       51
# 5         Marco Wilson  DB       51
# 6            J.J. Watt  DL       48
# 7      Victor Dimukeje  LB       42
# 8       Isaiah Simmons  DB       42
# 9            Leki Fotu  DL       42
# 10       Markus Golden  LB       42
# 11         Ben Niemann  LB       37
# 12      Tanner Vallejo  LB       29
# 13  Jonathan Ledbetter  DL       25
# 14       Michael Dogbe  DL       14
# 15       Myjai Sanders  LB        8
# 16        Jesse Luketa  LB        8
# 17       Antwaun Woods  DL        7
# 18    Antonio Hamilton  DB        6
# 19         Chris Banjo  DB        4
# 20      Cameron Thomas  LB        4
# 21    Rashard Lawrence  DL        3
# 22      Ezekiel Turner  LB        1

# %%
all_players_sorted_7.head(2).T.tail(50)
# Out:
#                                         0           1
# o_nb                               256.35      126.12
# dir_nb                             231.23      185.75
# position                               RB          NT
# new_pos                                SK          DL
# bc_x                                83.86       83.86
# bc_y                                24.56       24.56
# dist_to_ball                          0.0    5.081388
# ang_to_ball                         180.0    3.836576
# within_3_yds                            1           0
# within_5_yds                            1           0
# frame_since_bc                          0           0
# rank                                  1.0         2.0
# x_no_1                              79.45       79.45
# y_no_1                              24.72       24.72
# x_no_2                              79.85       79.85
# y_no_2                              22.37       22.37
# x_no_3                              79.08       79.08
# y_no_3                               23.3        23.3
# x_no_4                              80.56       80.56
# y_no_4                              28.61       28.61
# x_no_5                              79.76       79.76
# y_no_5                              19.81       19.81
# x_no_6                              78.38       78.38
# y_no_6                              27.96       27.96
# x_no_7                              79.18       79.18
# y_no_7                              17.97       17.97
# dist_closest_o_bc                4.412902     0.82801
# ang_closest_o_bc               177.922153   37.146687
# dist_2_closest_o_bc              4.569048    2.132159
# ang_2_closest_o_bc             208.640484  299.811543
# dist_3_closest_o_bc              4.943278    0.964624
# ang_3_closest_o_bc             194.767161  287.495758
# dist_4_closest_o_bc              5.224222    4.733392
# ang_4_closest_o_bc             129.173658   68.041247
# dist_5_closest_o_bc              6.274751    4.515418
# ang_5_closest_o_bc             229.200622   282.40494
# dist_6_closest_o_bc              6.449062    3.762406
# ang_6_closest_o_bc             148.182965   96.256106
# dist_7_closest_o_bc              8.082728    6.262156
# ang_7_closest_o_bc              234.61889  273.570627
# min_distance                     4.569048    0.964624
# angle_for_min_distance         208.640484  287.495758
# second_min_distance              4.943278    2.132159
# angle_for_second_min_distance  194.767161  299.811543
# max_distance                        73.86       73.86
# actual_dist_from_final              22.74       22.74
# std_x_nb                            83.86       78.79
# std_y_nb                            24.56       24.22
# std_bc_x                            83.86       83.86
# std_bc_y                            24.56       24.56

# %%
tackle_data
# Out:
#                      def1_pos defensiveTeam possessionTeam  new_prop  week  \
# def1_name
# Budda Baker                DB           ARI             NO  0.679478     7
# Jalen Thompson             DB           ARI             NO  0.320522     7
# Rashard Lawrence           DL           ARI             NO  0.641223     7
# Zaven Collins              LB           ARI             NO  0.358777     7
# Tyrann Mathieu             DB            NO            ARI  0.511015     7
# ...                       ...           ...            ...       ...   ...
# Marcus Maye                DB            NO            BAL  0.294283     9
# Kaden Elliss               LB            NO            BAL  0.705717     9
# Carl Granderson            DL            NO            BAL  1.000000     9
# Broderick Washington       DL           BAL             NO  0.552720     9
# Travis Jones               DL           BAL             NO  0.447280     9
#
#                       third_down_failed  fourth_down_failed  3rd or 4th stop  \
# def1_name
# Budda Baker                           0                   0                0
# Jalen Thompson                        0                   0                0
# Rashard Lawrence                      0                   0                0
# Zaven Collins                         0                   0                0
# Tyrann Mathieu                        0                   0                0
# ...                                 ...                 ...              ...
# Marcus Maye                           0                   0                0
# Kaden Elliss                          0                   0                0
# Carl Granderson                       1                   0                1
# Broderick Washington                  0                   0                0
# Travis Jones                          0                   0                0
#
#                       goal_to_go  tackled_for_loss  ... run_location  \
# def1_name                                           ...
# Budda Baker                    0                 0  ...       middle
# Jalen Thompson                 0                 0  ...       middle
# Rashard Lawrence               0                 0  ...       middle
# Zaven Collins                  0                 0  ...       middle
# Tyrann Mathieu                 0                 0  ...       middle
# ...                          ...               ...  ...          ...
# Marcus Maye                    0                 0  ...        right
# Kaden Elliss                   0                 0  ...        right
# Carl Granderson                0                 1  ...         left
# Broderick Washington           0                 0  ...        right
# Travis Jones                   0                 0  ...        right
#
#                      run_gap_location 3rd or 4th failed       epa  neg epa  \
# def1_name
# Budda Baker                    middle                 0  1.318386        0
# Jalen Thompson                 middle                 0  1.318386        0
# Rashard Lawrence               middle                 0 -0.152057        1
# Zaven Collins                  middle                 0 -0.152057        1
# Tyrann Mathieu                 middle                 0  0.279343        0
# ...                               ...               ...       ...      ...
# Marcus Maye                 right end                 0 -0.149736        1
# Kaden Elliss                right end                 0 -0.149736        1
# Carl Granderson              left end                 1 -1.144850        1
# Broderick Washington      right guard                 0 -0.099311        1
# Travis Jones              right guard                 0 -0.099311        1
#
#                       sum prod neg epa  3rd or 4th  goal to go  TFL     epa.1
# def1_name
# Budda Baker                   0.000000         0.0         0.0  0.0  0.895815
# Jalen Thompson                0.000000         0.0         0.0  0.0  0.422572
# Rashard Lawrence              0.641223         0.0         0.0  0.0 -0.097502
# Zaven Collins                 0.358777         0.0         0.0  0.0 -0.054555
# Tyrann Mathieu                0.000000         0.0         0.0  0.0  0.142748
# ...                                ...         ...         ...  ...       ...
# Marcus Maye                   0.294283         0.0         0.0  0.0 -0.044065
# Kaden Elliss                  0.705717         0.0         0.0  0.0 -0.105671
# Carl Granderson               1.000000         1.0         0.0  1.0 -1.144850
# Broderick Washington          0.552720         0.0         0.0  0.0 -0.054891
# Travis Jones                  0.447280         0.0         0.0  0.0 -0.044420
#
# [3322 rows x 21 columns]

# %%
app = dash.Dash(__name__)

# App Layout
app.layout = html.Div([
    dcc.Dropdown(
        id='team-dropdown',
        options=[{'label': team, 'value': team} for team in tackle_data['defensiveTeam'].unique()],
        value=tackle_data['defensiveTeam'].unique()[0]
    ),
    dcc.Dropdown(
        id='week-dropdown',
        options=[{'label': week, 'value': week} for week in tackle_data['week'].unique()],
        value=tackle_data['week'].unique()[0]
    ),
    dcc.Graph(id='heatmap')
])

# Callback for updating the heatmap
@app.callback(
    Output('heatmap', 'figure'),
    [Input('team-dropdown', 'value'), Input('week-dropdown', 'value')]
)
def update_heatmap(selected_team, selected_week):
    try:

        print(f"Selected team: {selected_team}, week: {selected_week}")  # Debug print

        # Filtered data for selected team and week
        team_data = tackle_data[(tackle_data['defensiveTeam'] == selected_team) & (tackle_data['week'] == selected_week)]
        team_summary = team_data.groupby(['run_gap_location', 'def1_pos']).sum()['new_prop'].reset_index()

        # Filtered data for all teams in the selected week
        week_data = tackle_data[tackle_data['week'] == selected_week]
        week_summary = week_data.groupby(['run_gap_location', 'def1_pos']).sum()['new_prop'].reset_index()

        # Normalize week_summary data by row
        week_summary['new_prop'] = week_summary.groupby('run_gap_location')['new_prop'].apply(lambda x: x / x.sum())


        # Debugging: Print the team_summary and week_summary dataframes
        print("Team Summary:\n", team_summary)
        print("Week Summary:\n", week_summary)



        # Create the figure
        fig = make_subplots(rows=1, cols=2, subplot_titles=("Team Specific", "All Teams"))

        # Team-specific heatmap
        fig.add_trace(
            go.Heatmap(
                x=team_summary['def1_pos'],
                y=team_summary['run_gap_location'],
                z=team_summary['new_prop'],
                coloraxis="coloraxis"
            ),
            row=1, col=1
        )

        # All teams heatmap
        fig.add_trace(
            go.Heatmap(
                x=week_summary['def1_pos'],
                y=week_summary['run_gap_location'],
                z=week_summary['new_prop'],
                coloraxis="coloraxis"
            ),
            row=1, col=2
        )

        # Update layout
        fig.update_layout(coloraxis=dict(colorscale='Viridis'), showlegend=False)

        return fig
    except Exception as e:
        print(f"Error in callback: {e}")
        return go.Figure()

# Run the Dash app
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
results_df_7_9 = results_df_7_9.reset_index(drop=True)

# %%
results_df_7_9.head(60)
# Out:
#         gameId  playId  frameId  actual_dist_from_final  max_distance  \
# 0   2022102000      80       18                   22.74         73.86
# 1   2022102000      80       19                   22.32         73.44
# 2   2022102000      80       20                   21.87         72.99
# 3   2022102000      80       21                   21.38         72.50
# 4   2022102000      80       22                   20.85         71.97
# 5   2022102000      80       23                   20.28         71.40
# 6   2022102000      80       24                   19.69         70.81
# 7   2022102000      80       25                   19.06         70.18
# 8   2022102000      80       26                   18.41         69.53
# 9   2022102000      80       27                   17.74         68.86
# 10  2022102000      80       28                   17.05         68.17
# 11  2022102000      80       29                   16.35         67.47
# 12  2022102000      80       30                   15.62         66.74
# 13  2022102000      80       31                   14.90         66.02
# 14  2022102000      80       32                   14.17         65.29
# 15  2022102000      80       33                   13.45         64.57
# 16  2022102000      80       34                   12.72         63.84
# 17  2022102000      80       35                   12.00         63.12
# 18  2022102000      80       36                   11.29         62.41
# 19  2022102000      80       37                   10.57         61.69
# 20  2022102000      80       38                    9.85         60.97
# 21  2022102000      80       39                    9.15         60.27
# 22  2022102000      80       40                    8.47         59.59
# 23  2022102000      80       41                    7.83         58.95
# 24  2022102000      80       42                    7.23         58.35
# 25  2022102000      80       43                    6.68         57.80
# 26  2022102000      80       44                    6.18         57.30
# 27  2022102000      80       45                    5.72         56.84
# 28  2022102000      80       46                    5.29         56.41
# 29  2022102000      80       47                    4.89         56.01
# 30  2022102000      80       48                    4.51         55.63
# 31  2022102000      80       49                    4.16         55.28
# 32  2022102000      80       50                    3.74         54.86
# 33  2022102000      80       51                    3.33         54.45
# 34  2022102000      80       52                    2.89         54.01
# 35  2022102000      80       53                    2.45         53.57
# 36  2022102000      80       54                    2.02         53.14
# 37  2022102000      80       55                    1.59         52.71
# 38  2022102000      80       56                    1.15         52.27
# 39  2022102000      80       57                    0.73         51.85
# 40  2022102000      80       58                    0.31         51.43
# 41  2022102000      80       59                    0.00         51.12
# 42  2022102000     101       18                    9.31         57.27
# 43  2022102000     101       19                    8.89         56.85
# 44  2022102000     101       20                    8.43         56.39
# 45  2022102000     101       21                    7.95         55.91
# 46  2022102000     101       22                    7.44         55.40
# 47  2022102000     101       23                    6.91         54.87
# 48  2022102000     101       24                    6.37         54.33
# 49  2022102000     101       25                    5.84         53.80
# 50  2022102000     101       26                    5.33         53.29
# 51  2022102000     101       27                    4.82         52.78
# 52  2022102000     101       28                    4.33         52.29
# 53  2022102000     101       29                    3.85         51.81
# 54  2022102000     101       30                    3.40         51.36
# 55  2022102000     101       31                    2.94         50.90
# 56  2022102000     101       32                    2.55         50.51
# 57  2022102000     101       33                    2.22         50.18
# 58  2022102000     101       34                    1.87         49.83
# 59  2022102000     101       35                    1.56         49.52
#
#     Predicted
# 0    8.613031
# 1    7.954155
# 2    8.515083
# 3    7.202409
# 4    7.968444
# 5    8.502591
# 6   10.338212
# 7    9.951587
# 8   11.695140
# 9   15.126421
# 10  15.186343
# 11  13.827688
# 12  16.188288
# 13  12.326735
# 14  13.757059
# 15  11.554759
# 16  14.363513
# 17   9.802099
# 18  10.484894
# 19   8.696413
# 20   7.969340
# 21   4.283415
# 22   4.043005
# 23   5.502129
# 24   5.254302
# 25   3.636310
# 26   3.668035
# 27   2.612698
# 28   2.096569
# 29   3.039857
# 30   3.859840
# 31   2.947954
# 32   3.236094
# 33   3.284275
# 34   2.862344
# 35   4.430527
# 36   4.189385
# 37   6.194710
# 38   5.111487
# 39   4.377732
# 40   3.505994
# 41   2.228987
# 42  10.595116
# 43   8.803803
# 44  11.186538
# 45  11.289844
# 46  10.327088
# 47   9.689335
# 48   9.332753
# 49   7.694292
# 50   5.308436
# 51   4.961886
# 52   4.118184
# 53   3.635324
# 54   3.303832
# 55   3.094280
# 56   2.839362
# 57   2.517326
# 58   2.154928
# 59   1.823906

# %%
all_predicted_7 = results_df_7_9[['gameId', 'playId', 'frameId', 'Predicted']].merge(all_players_sorted_7, on=['gameId', 'playId', 'frameId'], how='inner')

# %%
all_predicted_7

# %%
all_predicted_7 = results_df_7_9[['gameId', 'playId', 'frameId', 'Predicted']].merge(all_players_sorted_7, on=['gameId', 'playId', 'frameId'], how='inner')



def polar_to_cartesian(row):
    # Convert angle to radians and calculate x, y coordinates
    angle_rad = np.radians(row['angle_for_min_distance'])
    x = row['std_x_nb'] + row['min_distance'] * np.cos(angle_rad)
    y = row['std_y_nb'] + row['min_distance'] * np.sin(angle_rad)
    return x, y

def polar_to_cartesian_2(row):
    # Convert angle to radians and calculate x, y coordinates
    angle_rad = np.radians(row['angle_for_second_min_distance'])
    x = row['std_x_nb'] + row['second_min_distance'] * np.cos(angle_rad)
    y = row['std_y_nb'] + row['second_min_distance'] * np.sin(angle_rad)
    return x, y


  df_7 = all_predicted_7[['gameId','playId','frameId','Predicted',
 'dist_to_ball',
 'ang_to_ball',
 'within_3_yds',
 'within_5_yds',
 'frame_since_bc',
 'rank',
 'new_pos',
 'x_no_1',
 'y_no_1',
 'min_distance',
 'angle_for_min_distance',
 'second_min_distance',
 'angle_for_second_min_distance',
 'max_distance',
 'actual_dist_from_final',
 'std_x_nb',
 'std_y_nb',
 'std_bc_x',
 'std_bc_y']]

# %%
df_7 = all_predicted_7[['gameId','playId','frameId','Predicted',
 'dist_to_ball',
 'ang_to_ball',
 'within_3_yds',
 'within_5_yds',
 'frame_since_bc',
 'rank',
 'new_pos',
 'x_no_1',
 'y_no_1',
 'min_distance',
 'angle_for_min_distance',
 'second_min_distance',
 'angle_for_second_min_distance',
 'max_distance',
 'actual_dist_from_final',
 'std_x_nb',
 'std_y_nb',
 'std_bc_x',
 'std_bc_y']]

# %%
all_predicted_7 = results_df_7_9[['gameId', 'playId', 'frameId', 'Predicted']].merge(all_players_sorted_7, on=['gameId', 'playId', 'frameId'], how='inner')



def polar_to_cartesian(row):
    # Convert angle to radians and calculate x, y coordinates
    angle_rad = np.radians(row['angle_for_min_distance'])
    x = row['std_x_nb'] + row['min_distance'] * np.cos(angle_rad)
    y = row['std_y_nb'] + row['min_distance'] * np.sin(angle_rad)
    return x, y

def polar_to_cartesian_2(row):
    # Convert angle to radians and calculate x, y coordinates
    angle_rad = np.radians(row['angle_for_second_min_distance'])
    x = row['std_x_nb'] + row['second_min_distance'] * np.cos(angle_rad)
    y = row['std_y_nb'] + row['second_min_distance'] * np.sin(angle_rad)
    return x, y


  df_7 = all_predicted_7[['gameId','playId','frameId','Predicted',
 'dist_to_ball',
 'ang_to_ball',
 'within_3_yds',
 'within_5_yds',
 'frame_since_bc',
 'rank',
 'new_pos',
 'x_no_1',
 'y_no_1',
 'min_distance',
 'angle_for_min_distance',
 'second_min_distance',
 'angle_for_second_min_distance',
 'max_distance',
 'actual_dist_from_final',
 'std_x_nb',
 'std_y_nb',
 'std_bc_x',
 'std_bc_y']]


df_7['closest_o_x'], df_7['closest_o_y'] = zip(*all_predicted_7.apply(polar_to_cartesian, axis=1))
df_7['second_closest_o_x'], df_7['second_closest_o_y'] = zip(*all_predicted_7.apply(polar_to_cartesian_2, axis=1))

df_7 = df_7[df_7['rank'] > 1.5]


import plotly.graph_objects as go

# Filter for a specific play
specific_game_id = 2022102000
specific_play_id = 80
play_data = df_7[(df_7['gameId'] == specific_game_id) & (df_7['playId'] == specific_play_id)]

# Get unique frames
unique_frames = sorted(play_data['frameId'].unique())

# Initialize the figure
fig = go.Figure()

# Create frames for each unique frame in the play
frames = []
for frame_id in unique_frames:
    frame_data = play_data[play_data['frameId'] == frame_id]
    frame_traces = []

    # Add trace for defensive player
    frame_traces.append(
        go.Scatter(
            x=frame_data['std_x_nb'],
            y=frame_data['std_y_nb'],
            mode='markers',
            marker=dict(size=10, color='blue', symbol='circle'),
            name='Defensive Player'
        )
    )

    # Add trace for ball carrier
    frame_traces.append(
        go.Scatter(
            x=frame_data['std_bc_x'],
            y=frame_data['std_bc_y'],
            mode='markers',
            marker=dict(size=12, color='red', symbol='star'),
            name='Ball Carrier'
        )
    )

    # Add traces for offensive players
    for col_x, col_y in [('x_no_1', 'y_no_1'), ('closest_o_x', 'closest_o_y'), ('second_closest_o_x', 'second_closest_o_y')]:
        if col_x in frame_data and col_y in frame_data:
            frame_traces.append(
                go.Scatter(
                    x=frame_data[col_x],
                    y=frame_data[col_y],
                    mode='markers',
                    marker=dict(size=8, color='green', symbol='square'),
                    name='Offensive Player'
                )
            )


    frames.append(go.Frame(data=frame_traces, name=str(frame_id)))

    # Calculate positions for vertical lines
    ball_carrier_x = frame_data['std_bc_x'].iloc[0]  # Assuming there's only one ball carrier per frame
    actual_line_x = ball_carrier_x - frame_data['actual_dist_from_final'].iloc[0]
    predicted_line_x = ball_carrier_x - frame_data['Predicted'].iloc[0]

    # Add vertical lines as shapes
    frame_shapes = [
        go.layout.Shape(
            type="line",
            x0=actual_line_x, y0=0, x1=actual_line_x, y1=55,  # y1 should be the top of your y-axis
            line=dict(color="yellow", width=2)
        ),
        go.layout.Shape(
            type="line",
            x0=predicted_line_x, y0=0, x1=predicted_line_x, y1=55,
            line=dict(color="white", width=2)
        )
    ]


    # Add this set of traces as a frame
    frames.append(go.Frame(data=frame_traces, name=str(frame_id), layout=go.Layout(shapes=frame_shapes)))



    # # Add this set of traces as a frame
    # frames.append(go.Frame(data=frame_traces, name=str(frame_id)))

# Set frames to the figure
fig.frames = frames

# Update layout for animation
fig.update_layout(
    title=f'Game {specific_game_id} Play {specific_play_id} Player Movements',
    xaxis=dict(title='X Coordinate', range=[0, 110]),
    yaxis=dict(title='Y Coordinate', range=[0, 55]),
    updatemenus=[{
        'type': 'buttons',
        'buttons': [{
            'label': 'Play',
            'method': 'animate',
            'args': [None, {'frame': {'duration': 500, 'redraw': True}, 'fromcurrent': True}]
        }]
    }],
    sliders=[{
        'steps': [{'method': 'animate', 'args': [[str(frame_id)], {'mode': 'immediate', 'frame': {'duration': 500, 'redraw': True}}], 'label': str(frame_id)} for frame_id in unique_frames]
    }]
)

# Initialize the figure with the first frame's data
initial_frame_data = play_data[play_data['frameId'] == unique_frames[0]]
fig.add_traces(frames[0]['data'])

fig.show()
# Out:
# <ipython-input-60-c8c4d5011105>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-60-c8c4d5011105>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_7['second_closest_o_x'], df_7['second_closest_o_y'] = zip(*all_predicted_7.apply(polar_to_cartesian_2, axis=1))
# Out:
# <ipython-input-61-8bd930daee39>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-61-8bd930daee39>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_7 = df_7[df_7['rank'] > 1.5]

# %%
df_7
# Out:
#            gameId playId frameId  Predicted  dist_to_ball  ang_to_ball  \
# 1      2022102000     80      18   8.613031      5.081388     3.836576
# 2      2022102000     80      18   8.613031      5.393403    26.660069
# 3      2022102000     80      18   8.613031      6.099459   312.873987
# 5      2022102000     80      19   7.954155      4.722457     5.589869
# 6      2022102000     80      19   7.954155      5.014828    29.376425
# ...           ...    ...     ...        ...           ...          ...
# 84230  2022102400   3698      45  -0.118250      0.622415   293.682088
# 84231  2022102400   3698      45  -0.118250      1.030194   271.112400
# 84233  2022102400   3698      46  -0.252221      0.604070   199.334809
# 84234  2022102400   3698      46  -0.252221      0.652993   297.349876
# 84235  2022102400   3698      46  -0.252221      1.036967   276.645278
#
#        within_3_yds  within_5_yds  frame_since_bc  rank  ... max_distance  \
# 1                 0             0               0   2.0  ...        73.86
# 2                 0             0               0   3.0  ...        73.86
# 3                 0             0               0   4.0  ...        73.86
# 5                 0             1               1   2.0  ...        73.44
# 6                 0             0               1   3.0  ...        73.44
# ...             ...           ...             ...   ...  ...          ...
# 84230             1             1              27   3.0  ...         1.95
# 84231             1             1              27   4.0  ...         1.95
# 84233             1             1              28   2.0  ...         2.05
# 84234             1             1              28   3.0  ...         2.05
# 84235             1             1              28   4.0  ...         2.05
#
#        actual_dist_from_final  std_x_nb  std_y_nb  std_bc_x  std_bc_y  \
# 1                       22.74     78.79     24.22     83.86     24.56
# 2                       22.74     79.04     22.14     83.86     24.56
# 3                       22.74     79.71     29.03     83.86     24.56
# 5                       22.32     78.74     23.78     83.44     24.24
# 6                       22.32     79.07     21.78     83.44     24.24
# ...                       ...       ...       ...       ...       ...
# 84230                    -0.1     11.70     25.29     11.95     24.72
# 84231                    -0.1     11.93     25.75     11.95     24.72
# 84233                     0.0     12.62     24.75     12.05     24.55
# 84234                     0.0     11.75     25.13     12.05     24.55
# 84235                     0.0     11.93     25.58     12.05     24.55
#
#        closest_o_x closest_o_y second_closest_o_x  second_closest_o_y
# 1            79.08       23.30              79.85               22.37
# 2            79.85       22.37              79.08               23.30
# 3            80.56       28.61              78.38               27.96
# 5            78.99       22.91              79.84               22.06
# 6            79.84       22.06              78.99               22.91
# ...            ...         ...                ...                 ...
# 84230        10.10       27.05              10.71               28.05
# 84231        10.10       27.05              10.71               28.05
# 84233        10.05       26.86              10.68               27.87
# 84234        10.05       26.86              10.68               27.87
# 84235        10.05       26.86              10.68               27.87
#
# [63177 rows x 27 columns]

# %%
import plotly.graph_objects as go

# Filter for a specific play
specific_game_id = 2022102000
specific_play_id = 80
play_data = df_7[(df_7['gameId'] == specific_game_id) & (df_7['playId'] == specific_play_id)]

# Get unique frames
unique_frames = sorted(play_data['frameId'].unique())

# Initialize the figure
fig = go.Figure()

# Create frames for each unique frame in the play
frames = []
for frame_id in unique_frames:
    frame_data = play_data[play_data['frameId'] == frame_id]
    frame_traces = []

    # Add trace for defensive player
    frame_traces.append(
        go.Scatter(
            x=frame_data['std_x_nb'],
            y=frame_data['std_y_nb'],
            mode='markers',
            marker=dict(size=10, color='blue', symbol='circle'),
            name='Defensive Player'
        )
    )

    # Add trace for ball carrier
    frame_traces.append(
        go.Scatter(
            x=frame_data['std_bc_x'],
            y=frame_data['std_bc_y'],
            mode='markers',
            marker=dict(size=12, color='red', symbol='star'),
            name='Ball Carrier'
        )
    )

    # Add traces for offensive players
    for col_x, col_y in [('x_no_1', 'y_no_1'), ('closest_o_x', 'closest_o_y'), ('second_closest_o_x', 'second_closest_o_y')]:
        if col_x in frame_data and col_y in frame_data:
            frame_traces.append(
                go.Scatter(
                    x=frame_data[col_x],
                    y=frame_data[col_y],
                    mode='markers',
                    marker=dict(size=8, color='green', symbol='square'),
                    name='Offensive Player'
                )
            )


    frames.append(go.Frame(data=frame_traces, name=str(frame_id)))

    # Calculate positions for vertical lines
    ball_carrier_x = frame_data['std_bc_x'].iloc[0]  # Assuming there's only one ball carrier per frame
    actual_line_x = ball_carrier_x - frame_data['actual_dist_from_final'].iloc[0]
    predicted_line_x = ball_carrier_x - frame_data['Predicted'].iloc[0]

    # Add vertical lines as shapes
    frame_shapes = [
        go.layout.Shape(
            type="line",
            x0=actual_line_x, y0=0, x1=actual_line_x, y1=55,  # y1 should be the top of your y-axis
            line=dict(color="yellow", width=2)
        ),
        go.layout.Shape(
            type="line",
            x0=predicted_line_x, y0=0, x1=predicted_line_x, y1=55,
            line=dict(color="white", width=2)
        )
    ]


    # Add this set of traces as a frame
    frames.append(go.Frame(data=frame_traces, name=str(frame_id), layout=go.Layout(shapes=frame_shapes)))



    # # Add this set of traces as a frame
    # frames.append(go.Frame(data=frame_traces, name=str(frame_id)))

# Set frames to the figure
fig.frames = frames

# Update layout for animation
fig.update_layout(
    title=f'Game {specific_game_id} Play {specific_play_id} Player Movements',
    xaxis=dict(title='X Coordinate', range=[0, 110]),
    yaxis=dict(title='Y Coordinate', range=[0, 55]),
    updatemenus=[{
        'type': 'buttons',
        'buttons': [{
            'label': 'Play',
            'method': 'animate',
            'args': [None, {'frame': {'duration': 500, 'redraw': True}, 'fromcurrent': True}]
        }]
    }],
    sliders=[{
        'steps': [{'method': 'animate', 'args': [[str(frame_id)], {'mode': 'immediate', 'frame': {'duration': 500, 'redraw': True}}], 'label': str(frame_id)} for frame_id in unique_frames]
    }]
)

# Initialize the figure with the first frame's data
initial_frame_data = play_data[play_data['frameId'] == unique_frames[0]]
fig.add_traces(frames[0]['data'])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a229510e-e35d-4786-9625-eb40dc31867f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a229510e-e35d-4786-9625-eb40dc31867f")) {                    Plotly.newPlot(                        "a229510e-e35d-4786-9625-eb40dc31867f",                        [{"marker":{"color":"blue","size":10,"symbol":"circle"},"mode":"markers","name":"Defensive Player","x":[78.79,79.04,79.71],"y":[24.22,22.14,29.03],"type":"scatter"},{"marker":{"color":"red","size":12,"symbol":"star"},"mode":"markers","name":"Ball Carrier","x":[83.86,83.86,83.86],"y":[24.56,24.56,24.56],"type":"scatter"},{"marker":{"color":"green","size":8,"symbol":"square"},"mode":"markers","name":"Offensive Player","x":[79.45,79.45,79.45],"y":[24.72,24.72,24.72],"type":"scatter"},{"marker":{"color":"green","size":8,"symbol":"square"},"mode":"markers","name":"Offensive Player","x":[79.08,79.85,80.56],"y":[23.3,22.37,28.61],"type":"scatter"},{"marker":{"color":"green","size":8,"symbol":"square"},"mode":"markers","name":"Offensive Player","x":[79.85,79.08,78.38],"y":[22.37,23.3,27.96],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"typ ...
